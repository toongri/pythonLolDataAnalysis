# %% [markdown]
# ## 데이터 시각화

# %% [markdown]
# - anaconda prompt
# - conda install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cx_Oracle
import my_utils as mu

# %%
mu.db_open()
# Out:
# open!

# %%
match_df = mu.sql_excute('select * from match_data')

# %%
mu.db_close()
# Out:
# close!

# %%
match_df
# Out:
#              GAMEID  GAMEDURATION     GAMEVERSION     SUMMONERNAME  \
# 0     KR_5546419545          1454  11.22.406.3587             애신아씨
# 1     KR_5546419545          1454  11.22.406.3587           asdfas
# 2     KR_5546419545          1454  11.22.406.3587         내가무슨죄를졌어
# 3     KR_5369354045       1994882  11.15.389.2308  호이가계속되면그게둘린줄알아요
# 4     KR_5369354045       1994882  11.15.389.2308          하지마이쉑이야
# ...             ...           ...             ...              ...
# 2675  KR_5558516683          1348  11.22.406.3587      Youtube 편집자
# 2676  KR_5558516683          1348  11.22.406.3587             코마츠7
# 2677  KR_5558516683          1348  11.22.406.3587           계엄부사령관
# 2678  KR_5558516683          1348  11.22.406.3587             쿠찌비루
# 2679  KR_5558516683          1348  11.22.406.3587        BRO spoon
#
#       SUMMONERLEVEL  PARTICIPANTID CHAMPIONNAME  CHAMPEXPERIENCE TEAMPOSITION  \
# 0               198              8          Vex            11832       MIDDLE
# ...

# %%
match_df = match_df.sort_values(by=['GAMEID','PARTICIPANTID'], ascending=True)
match_df[:20]
# Out:
#              GAMEID  GAMEDURATION    GAMEVERSION SUMMONERNAME  SUMMONERLEVEL  \
# 1148  KR_4961178964       1660620  11.2.353.8505          뀨북이            447
# 1149  KR_4961178964       1660620  11.2.353.8505          기욱e             63
# 1150  KR_4961178964       1660620  11.2.353.8505       즐겜or던짐             34
# 1151  KR_4961178964       1660620  11.2.353.8505       너만의 원딜             34
# 1152  KR_4961178964       1660620  11.2.353.8505     약한공룡은피딩을             61
# 1153  KR_4961178964       1660620  11.2.353.8505          질문봇             43
# 1154  KR_4961178964       1660620  11.2.353.8505      JG Razt             40
# 1155  KR_4961178964       1660620  11.2.353.8505       outuri            294
# 1156  KR_4961178964       1660620  11.2.353.8505       쎈척하지마라            168
# 1157  KR_4961178964       1660620  11.2.353.8505         안돼그건            282
# 1158  KR_4961235887       2110016  11.2.353.8505          뀨북이            447
# ...

# %%
my_df = match_df[match_df.GAMEID=='KR_4961178964']
my_df
# Out:
#              GAMEID  GAMEDURATION    GAMEVERSION SUMMONERNAME  SUMMONERLEVEL  \
# 1148  KR_4961178964       1660620  11.2.353.8505          뀨북이            447
# 1149  KR_4961178964       1660620  11.2.353.8505          기욱e             63
# 1150  KR_4961178964       1660620  11.2.353.8505       즐겜or던짐             34
# 1151  KR_4961178964       1660620  11.2.353.8505       너만의 원딜             34
# 1152  KR_4961178964       1660620  11.2.353.8505     약한공룡은피딩을             61
# 1153  KR_4961178964       1660620  11.2.353.8505          질문봇             43
# 1154  KR_4961178964       1660620  11.2.353.8505      JG Razt             40
# 1155  KR_4961178964       1660620  11.2.353.8505       outuri            294
# 1156  KR_4961178964       1660620  11.2.353.8505       쎈척하지마라            168
# 1157  KR_4961178964       1660620  11.2.353.8505         안돼그건            282
#
#       PARTICIPANTID CHAMPIONNAME  CHAMPEXPERIENCE TEAMPOSITION  TEAMID    WIN  \
# ...

# %%
my_df.set_index('SUMMONERNAME', inplace=True)

# %%
my_df = my_df['TOTALDAMAGEDEALTTOCHAMPIONS']
my_df
# Out:
# SUMMONERNAME
# 뀨북이         14812
# 기욱e         14507
# 즐겜or던짐      26856
# 너만의 원딜      16533
# 약한공룡은피딩을     4753
# 질문봇         10758
# JG Razt      6932
# outuri       8122
# 쎈척하지마라      36355
# 안돼그건         7382
# Name: TOTALDAMAGEDEALTTOCHAMPIONS, dtype: int64

# %%
plt.plot(my_df, color='blue', linestyle='solid', marker='o')
# Out:
# C:\ProgramData\Anaconda3\envs\py36\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\envs\py36\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50865 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\envs\py36\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51600 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\envs\py36\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44188 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\envs\py36\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45912 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/gulim.ttc"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
plt.plot(my_df, color='blue', linestyle='solid', marker='o')

# %%
plt.xticks(rotation=45)
plt.plot(my_df, color='red', linestyle='solid', marker='o')

# %%
yticks_interval = 10000
maxlim = (int(my_df.max() / yticks_interval)+1) * yticks_interval
values = np.arange(0, maxlim + 1, yticks_interval)
plt.yticks(values, ['%s' % format(val,',') for val in values])
# Out:
# ([<matplotlib.axis.YTick at 0x1b02317aac8>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 10000, '10,000'),
#   Text(0, 20000, '20,000'),
#   Text(0, 30000, '30,000'),
#   Text(0, 40000, '40,000')])

# %%
yticks_interval = 10000
maxlim = (int(my_df.max() / yticks_interval)+1) * yticks_interval
values = np.arange(0, maxlim + 1, yticks_interval)
plt.yticks(values, ['%s' % format(val,',') for val in values])

plt.grid(True)
plt.title('그래프')
plt.xlabel('x축 제목')
plt.ylabel('y축 제목')
# Out:
# Text(0, 0.5, 'y축 제목')

# %%
my_df
# Out:
# SUMMONERNAME
# 뀨북이         14812
# 기욱e         14507
# 즐겜or던짐      26856
# 너만의 원딜      16533
# 약한공룡은피딩을     4753
# 질문봇         10758
# JG Razt      6932
# outuri       8122
# 쎈척하지마라      36355
# 안돼그건         7382
# Name: TOTALDAMAGEDEALTTOCHAMPIONS, dtype: int64

# %%
yticks_interval = 5000
maxlim = (int(my_df.max() / yticks_interval)+1) * yticks_interval
values = np.arange(0, maxlim + 1, yticks_interval)
plt.yticks(values, ['%s' % format(val, ',') for val in values])

plt.grid(True)
plt.xlabel('소환사 명')
plt.ylabel('챔피언에게 가한 딜량')
plt.title('딜량 그래프')

plt.xticks(rotation=45)
plt.plot(my_df, color='blue', linestyle='solid', marker='o')
