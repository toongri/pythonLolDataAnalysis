# %% [markdown]
# Split

# %%
s = 'League of Lengends'

# %%
print(s)
# Out:
# League of Lengends

# %%
s2 = s.split(' ')

# %%
print(s2)
# Out:
# ['League', 'of', 'Lengends']

# %%
type(s2)
# Out:
# list

# %%
'.'.join(s2)
# Out:
# 'League.of.Lengends'

# %%
'|'.join(s2)
# Out:
# 'League|of|Lengends'

# %% [markdown]
# replace

# %%
s
# Out:
# 'League of Lengends'

# %%
s.replace('of','_')
# Out:
# 'League _ Lengends'

# %% [markdown]
# - dict
# - key, value

# %%
dic = {}

# %%
type(dic)
# Out:
# dict

# %%
dic['a'] = 1
dic['b'] = '1'
dic['c'] = 'test'

# %%
dic
# Out:
# {'a': 1, 'b': '1', 'c': 'test'}

# %%
dic['b']
# Out:
# '1'

# %%
type(dic['b'])
# Out:
# str

# %%
type(dic['a'])
# Out:
# int

# %%
dic['b'] + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-980e9be2624f> in <module>
# ----> 1 dic['b'] + 2
#
# TypeError: must be str, not int

# %%
num = int(dic['b'])

# %%
type(num)
# Out:
# int

# %%
int(dic['b']) + 2
# Out:
# 3

# %%
str(1)
# Out:
# '1'

# %% [markdown]
# - list
# - set

# %%
list_tmp = ['녹턴','세트','가렌','럼블','세트']
list_tmp
# Out:
# ['녹턴', '세트', '가렌', '럼블', '세트']

# %%
set_tmp = {'녹턴','세트','가렌','럼블','세트'}
set_tmp
# Out:
# {'가렌', '녹턴', '럼블', '세트'}

# %% [markdown]
# - list_data -> set_data -> list_data
# - 중복 원소를 갖고있는 리스트에서 중복 제거한 효과

# %%
l1 = list(set(list_tmp))

# %%
l1
# Out:
# ['녹턴', '럼블', '세트', '가렌']

# %% [markdown]
# round

# %%
num1 = 3.141592

# %%
round(num1, 2)
# Out:
# 3.14

# %%
round(num1, 4)
# Out:
# 3.1416

# %% [markdown]
# function

# %%
def calc(n):
    res = n+0.123
    res = round(res, 2)
    return res

# %%
calc(num1)
# Out:
# 3.26

# %% [markdown]
# map lambda

# %%
lst = [3.56, 7.53323, 2.34, 10.1213]
lst
# Out:
# [3.56, 7.53323, 2.34, 10.1213]

# %%
for n in lst:
    res = round(n, 1)
    print(res)
# Out:
# 3.6
# 7.5
# 2.3
# 10.1

# %%
list(map(lambda x: round(x, 1),lst))
# Out:
# [3.6, 7.5, 2.3, 10.1]

# %%
list(map(lambda x: calc(x),lst))
# Out:
# [3.68, 7.66, 2.46, 10.24]

# %% [markdown]
# Try Except

# %%
lst = [1, 2, 3, '4', 5, 6]

# %%
for n in lst:
    res = n+0.5
    print(res)
# Out:
# 1.5
# 2.5
# 3.5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-9b4ad9fd453a> in <module>
#       1 for n in lst:
# ----> 2     res = n+0.5
#       3     print(res)
#
# TypeError: must be str, not float

# %%
for n in lst:
    try:
        print('정상')
        res = n+0.5
        print(res)
    except:
        print('except')
        res = int(n)+0.5
        print(res)
# Out:
# 정상
# 1.5
# 정상
# 2.5
# 정상
# 3.5
# 정상
# except
# 4.5
# 정상
# 5.5
# 정상
# 6.5

# %% [markdown]
# ## Anaconda Prompt
# - conda install xxxx
# - pip install xxxx

# %%
import pandas as pd

# %% [markdown]
# ### Series
# - 1차원 데이터

# %%
lst = ['Top', '녹턴']
lst
# Out:
# ['Top', '녹턴']

# %%
series = pd.Series(lst)

# %%
series
# Out:
# 0    Top
# 1     녹턴
# dtype: object

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series = pd.Series(lst, index=['lane','championName'])

# %%
series
# Out:
# lane            Top
# championName     녹턴
# dtype: object

# %%
dic = {}
dic['lane'] = 'Top'
dic['championName'] = '녹턴'

# %%
dic
# Out:
# {'lane': 'Top', 'championName': '녹턴'}

# %%
series = pd.Series(dic)

# %%
series
# Out:
# lane            Top
# championName     녹턴
# dtype: object

# %%
series.iloc[1]
# Out:
# '녹턴'

# %%
series.loc['lane']
# Out:
# 'Top'

# %%
series
# Out:
# lane            Top
# championName     녹턴
# dtype: object

# %%
tmp = pd.Series([3, 2, 4], index=['kills','deaths','assists'])

# %%
tmp
# Out:
# kills      3
# deaths     2
# assists    4
# dtype: int64

# %%
new_series = series.append(tmp)
new_series
# Out:
# lane            Top
# championName     녹턴
# kills             3
# deaths            2
# assists           4
# dtype: object

# %%
df = pd.DataFrame(new_series)
df
# Out:
#                 0
# lane          Top
# championName   녹턴
# kills           3
# deaths          2
# assists         4

# %%
df = pd.DataFrame([new_series])
df
# Out:
#   lane championName  kills  deaths  assists
# 0  Top           녹턴      3       2        4

# %%
lst = [['Top','세트',0,4,1], ['Middle','제드',3,1,1]]
print(lst)
# Out:
# [['Top', '세트', 0, 4, 1], ['Middle', '제드', 3, 1, 1]]

# %%
df2 = pd.DataFrame(lst)
df2
# Out:
#         0   1  2  3  4
# 0     Top  세트  0  4  1
# 1  Middle  제드  3  1  1

# %%
df2 = pd.DataFrame(lst, columns=['lane','championName','kills','deaths','assists'])
df2
# Out:
#      lane championName  kills  deaths  assists
# 0     Top           세트      0       4        1
# 1  Middle           제드      3       1        1

# %%
new_df = df.append(df2)
new_df
# Out:
#      lane championName  kills  deaths  assists
# 0     Top           녹턴      3       2        4
# 0     Top           세트      0       4        1
# 1  Middle           제드      3       1        1

# %%
new_df.iloc[[2]]
# Out:
#      lane championName  kills  deaths  assists
# 1  Middle           제드      3       1        1

# %%
new_df.loc[0]
# Out:
#   lane championName  kills  deaths  assists
# 0  Top           녹턴      3       2        4
# 0  Top           세트      0       4        1

# %%
new_df.reset_index()
# Out:
#    index    lane championName  kills  deaths  assists
# 0      0     Top           녹턴      3       2        4
# 1      0     Top           세트      0       4        1
# 2      1  Middle           제드      3       1        1

# %%
new_df
# Out:
#      lane championName  kills  deaths  assists
# 0     Top           녹턴      3       2        4
# 0     Top           세트      0       4        1
# 1  Middle           제드      3       1        1

# %%
new_df.reset_index(inplace = True)

# %%
new_df
# Out:
#    index    lane championName  kills  deaths  assists
# 0      0     Top           녹턴      3       2        4
# 1      0     Top           세트      0       4        1
# 2      1  Middle           제드      3       1        1

# %%
lst = [['Top','blue','세트',3,6,4], ['Top','red','녹턴',7,5,4],
       ['Jungle','blue','리신',2,2,4], ['Jungle','red','카서스',4,1,1],
       ['Middle','blue','르블랑',3,1,2], ['Middle','red','탈론',2,1,1]]

# %%
lst
# Out:
# [['Top', 'blue', '세트', 3, 6, 4],
#  ['Top', 'red', '녹턴', 7, 5, 4],
#  ['Jungle', 'blue', '리신', 2, 2, 4],
#  ['Jungle', 'red', '카서스', 4, 1, 1],
#  ['Middle', 'blue', '르블랑', 3, 1, 2],
#  ['Middle', 'red', '탈론', 2, 1, 1]]

# %%
df = pd.DataFrame(lst, columns=['lane', 'team', 'championName', 'kills', 'deaths', 'assists'])
df
# Out:
#      lane  team championName  kills  deaths  assists
# 0     Top  blue           세트      3       6        4
# 1     Top   red           녹턴      7       5        4
# 2  Jungle  blue           리신      2       2        4
# 3  Jungle   red          카서스      4       1        1
# 4  Middle  blue          르블랑      3       1        2
# 5  Middle   red           탈론      2       1        1

# %% [markdown]
# ## Sort

# %% [markdown]
# sort_values(by=[], ascending=False)

# %%
df_sort = df.sort_values(by=['kills','deaths'], ascending=False).reset_index()
df_sort
# Out:
#    index    lane  team championName  kills  deaths  assists
# 0      1     Top   red           녹턴      7       5        4
# 1      3  Jungle   red          카서스      4       1        1
# 2      0     Top  blue           세트      3       6        4
# 3      4  Middle  blue          르블랑      3       1        2
# 4      2  Jungle  blue           리신      2       2        4
# 5      5  Middle   red           탈론      2       1        1

# %%
df_sort.iloc[[2, 5]]
# Out:
#    index    lane  team championName  kills  deaths  assists
# 2      0     Top  blue           세트      3       6        4
# 5      5  Middle   red           탈론      2       1        1

# %% [markdown]
# ## GroupBy

# %%
df
# Out:
#      lane  team championName  kills  deaths  assists
# 0     Top  blue           세트      3       6        4
# 1     Top   red           녹턴      7       5        4
# 2  Jungle  blue           리신      2       2        4
# 3  Jungle   red          카서스      4       1        1
# 4  Middle  blue          르블랑      3       1        2
# 5  Middle   red           탈론      2       1        1

# %%
df.groupby(['lane']).mean()
# Out:
#         kills  deaths  assists
# lane
# Jungle    3.0     1.5      2.5
# Middle    2.5     1.0      1.5
# Top       5.0     5.5      4.0

# %%
df.groupby(['lane']).sum()
# Out:
#         kills  deaths  assists
# lane
# Jungle      6       3        5
# Middle      5       2        3
# Top        10      11        8

# %%
df.groupby(['lane'])[['kills', 'deaths', 'assists']].max()
# Out:
#         kills  deaths  assists
# lane
# Jungle      4       2        4
# Middle      3       1        2
# Top         7       6        4

# %%
df.groupby(['lane'])[['kills', 'deaths', 'assists']].min()
# Out:
#         kills  deaths  assists
# lane
# Jungle      2       1        1
# Middle      2       1        1
# Top         3       5        4

# %% [markdown]
# ### apply

# %%
df
# Out:
#      lane  team championName  kills  deaths  assists
# 0     Top  blue           세트      3       6        4
# 1     Top   red           녹턴      7       5        4
# 2  Jungle  blue           리신      2       2        4
# 3  Jungle   red          카서스      4       1        1
# 4  Middle  blue          르블랑      3       1        2
# 5  Middle   red           탈론      2       1        1

# %%
df['condition'] = 'none'
df
# Out:
#      lane  team championName  kills  deaths  assists condition
# 0     Top  blue           세트      3       6        4      none
# 1     Top   red           녹턴      7       5        4      none
# 2  Jungle  blue           리신      2       2        4      none
# 3  Jungle   red          카서스      4       1        1      none
# 4  Middle  blue          르블랑      3       1        2      none
# 5  Middle   red           탈론      2       1        1      none

# %%
df.iloc[[0]].deaths
# Out:
# 0    6
# Name: deaths, dtype: int64

# %%
df['condition'] = df.apply(lambda x: 'good' if(x.deaths < 3) else 'bad', axis=1)

# %%
df
# Out:
#      lane  team championName  kills  deaths  assists condition
# 0     Top  blue           세트      3       6        4       bad
# 1     Top   red           녹턴      7       5        4       bad
# 2  Jungle  blue           리신      2       2        4      good
# 3  Jungle   red          카서스      4       1        1      good
# 4  Middle  blue          르블랑      3       1        2      good
# 5  Middle   red           탈론      2       1        1      good

# %%
def test(x):
    if x < 2:
        return 'good'
    else:
        return 'bad'

# %%
df['condition'] = df.apply(lambda x: test(x.deaths), axis=1)

# %%
df
# Out:
#      lane  team championName  kills  deaths  assists condition
# 0     Top  blue           세트      3       6        4       bad
# 1     Top   red           녹턴      7       5        4       bad
# 2  Jungle  blue           리신      2       2        4       bad
# 3  Jungle   red          카서스      4       1        1      good
# 4  Middle  blue          르블랑      3       1        2      good
# 5  Middle   red           탈론      2       1        1      good

# %%
def test2(x):
    if x.deaths < 3:
        return 'good'
    else:
        return 'bad'

# %%
df.iloc[0]
# Out:
# lane             Top
# team            blue
# championName      세트
# kills              3
# deaths             6
# assists            4
# condition        bad
# Name: 0, dtype: object

# %%
df['condition'] = df.apply(lambda x: test2(x), axis=1)

# %%
df
# Out:
#      lane  team championName  kills  deaths  assists condition
# 0     Top  blue           세트      3       6        4       bad
# 1     Top   red           녹턴      7       5        4       bad
# 2  Jungle  blue           리신      2       2        4      good
# 3  Jungle   red          카서스      4       1        1      good
# 4  Middle  blue          르블랑      3       1        2      good
# 5  Middle   red           탈론      2       1        1      good

# %% [markdown]
# ### drop

# %%
df
# Out:
#      lane  team championName  kills  deaths  assists condition
# 0     Top  blue           세트      3       6        4       bad
# 1     Top   red           녹턴      7       5        4       bad
# 2  Jungle  blue           리신      2       2        4      good
# 3  Jungle   red          카서스      4       1        1      good
# 4  Middle  blue          르블랑      3       1        2      good
# 5  Middle   red           탈론      2       1        1      good

# %%
df.drop('condition', axis=1)
# Out:
#      lane  team championName  kills  deaths  assists
# 0     Top  blue           세트      3       6        4
# 1     Top   red           녹턴      7       5        4
# 2  Jungle  blue           리신      2       2        4
# 3  Jungle   red          카서스      4       1        1
# 4  Middle  blue          르블랑      3       1        2
# 5  Middle   red           탈론      2       1        1

# %%
df.drop('condition', axis=1, inplace=True)

# %%
df
# Out:
#      lane  team championName  kills  deaths  assists
# 0     Top  blue           세트      3       6        4
# 1     Top   red           녹턴      7       5        4
# 2  Jungle  blue           리신      2       2        4
# 3  Jungle   red          카서스      4       1        1
# 4  Middle  blue          르블랑      3       1        2
# 5  Middle   red           탈론      2       1        1

# %% [markdown]
# ## KDA
# - Kills, Deaths, Assists
# - (K+A)/D
# - df['kda']='none' 컬럼추가
# - apply 이용해서 함수 또는 한줄코딩으로 kda 계산

# %%
df['kda'] = 'none'
df
# Out:
#      lane  team championName  kills  deaths  assists   kda
# 0     Top  blue           세트      3       6        4  none
# 1     Top   red           녹턴      7       5        4  none
# 2  Jungle  blue           리신      2       2        4  none
# 3  Jungle   red          카서스      4       1        1  none
# 4  Middle  blue          르블랑      3       1        2  none
# 5  Middle   red           탈론      2       1        1  none

# %%
def calc_kda(k,d,a):
    kda = (k+a)/d
    return round(kda, 2)

# %%
df['kda'] = df.apply(lambda x: calc_kda(x.kills, x.deaths, x.assists), axis=1)

# %%
df
# Out:
#      lane  team championName  kills  deaths  assists   kda
# 0     Top  blue           세트      3       6        4  1.17
# 1     Top   red           녹턴      7       5        4  2.20
# 2  Jungle  blue           리신      2       2        4  3.00
# 3  Jungle   red          카서스      4       1        1  5.00
# 4  Middle  blue          르블랑      3       1        2  5.00
# 5  Middle   red           탈론      2       1        1  3.00

# %%
df['kda'] = df.apply(lambda x: round((x.kills+x.assists)/x.deaths, 2), axis=1)

# %%
df
# Out:
#      lane  team championName  kills  deaths  assists   kda
# 0     Top  blue           세트      3       6        4  1.17
# 1     Top   red           녹턴      7       5        4  2.20
# 2  Jungle  blue           리신      2       2        4  3.00
# 3  Jungle   red          카서스      4       1        1  5.00
# 4  Middle  blue          르블랑      3       1        2  5.00
# 5  Middle   red           탈론      2       1        1  3.00

# %%
blue_team = df[df.team == 'blue']
red_team = df[df.team == 'red']

# %%
blue_team
# Out:
#      lane  team championName  kills  deaths  assists   kda
# 0     Top  blue           세트      3       6        4  1.17
# 2  Jungle  blue           리신      2       2        4  3.00
# 4  Middle  blue          르블랑      3       1        2  5.00

# %%
red_team
# Out:
#      lane team championName  kills  deaths  assists  kda
# 1     Top  red           녹턴      7       5        4  2.2
# 3  Jungle  red          카서스      4       1        1  5.0
# 5  Middle  red           탈론      2       1        1  3.0

# %%
concat_df = pd.concat([blue_team, red_team])
concat_df
# Out:
#      lane  team championName  kills  deaths  assists   kda
# 0     Top  blue           세트      3       6        4  1.17
# 2  Jungle  blue           리신      2       2        4  3.00
# 4  Middle  blue          르블랑      3       1        2  5.00
# 1     Top   red           녹턴      7       5        4  2.20
# 3  Jungle   red          카서스      4       1        1  5.00
# 5  Middle   red           탈론      2       1        1  3.00

# %%
concat_df = pd.concat([blue_team, red_team], ignore_index=True)
concat_df
# Out:
#      lane  team championName  kills  deaths  assists   kda
# 0     Top  blue           세트      3       6        4  1.17
# 1  Jungle  blue           리신      2       2        4  3.00
# 2  Middle  blue          르블랑      3       1        2  5.00
# 3     Top   red           녹턴      7       5        4  2.20
# 4  Jungle   red          카서스      4       1        1  5.00
# 5  Middle   red           탈론      2       1        1  3.00

# %%
concat_df = pd.concat([blue_team, red_team], axis=1)
concat_df
# Out:
#      lane  team championName  kills  deaths  assists   kda    lane team  \
# 0     Top  blue           세트    3.0     6.0      4.0  1.17     NaN  NaN
# 1     NaN   NaN          NaN    NaN     NaN      NaN   NaN     Top  red
# 2  Jungle  blue           리신    2.0     2.0      4.0  3.00     NaN  NaN
# 3     NaN   NaN          NaN    NaN     NaN      NaN   NaN  Jungle  red
# 4  Middle  blue          르블랑    3.0     1.0      2.0  5.00     NaN  NaN
# 5     NaN   NaN          NaN    NaN     NaN      NaN   NaN  Middle  red
#
#   championName  kills  deaths  assists  kda
# 0          NaN    NaN     NaN      NaN  NaN
# 1           녹턴    7.0     5.0      4.0  2.2
# 2          NaN    NaN     NaN      NaN  NaN
# 3          카서스    4.0     1.0      1.0  5.0
# 4          NaN    NaN     NaN      NaN  NaN
# 5           탈론    2.0     1.0      1.0  3.0

# %% [markdown]
# ### merge
# - pd.merge(df_left, df_right, how='inner', on=None)

# %%
match_df = pd.merge(blue_team, red_team, on='lane')

# %%
match_df
# Out:
#      lane team_x championName_x  kills_x  deaths_x  assists_x  kda_x team_y  \
# 0     Top   blue             세트        3         6          4   1.17    red
# 1  Jungle   blue             리신        2         2          4   3.00    red
# 2  Middle   blue            르블랑        3         1          2   5.00    red
#
#   championName_y  kills_y  deaths_y  assists_y  kda_y
# 0             녹턴        7         5          4    2.2
# 1            카서스        4         1          1    5.0
# 2             탈론        2         1          1    3.0

# %%
col = ['lane','team_x','champName_blue','kills_blue','deaths_blue','assists_blue','kda_blue',
      'team_y','champName_red','kills_red','deaths_red','assists_red','kda_red']

# %%
match_df.columns = col

# %%
match_df
# Out:
#      lane team_x champName_blue  kills_blue  deaths_blue  assists_blue  \
# 0     Top   blue             세트           3            6             4
# 1  Jungle   blue             리신           2            2             4
# 2  Middle   blue            르블랑           3            1             2
#
#    kda_blue team_y champName_red  kills_red  deaths_red  assists_red  kda_red
# 0      1.17    red            녹턴          7           5            4      2.2
# 1      3.00    red           카서스          4           1            1      5.0
# 2      5.00    red            탈론          2           1            1      3.0

# %% [markdown]
# ### drop_duplicates
# - drop_duplicates(subset=none, keep='first', inplace=False, ignore_index=False)

# %%
match_df
# Out:
#      lane team_x champName_blue  kills_blue  deaths_blue  assists_blue  \
# 0     Top   blue             세트           3            6             4
# 1  Jungle   blue             리신           2            2             4
# 2  Middle   blue            르블랑           3            1             2
#
#    kda_blue team_y champName_red  kills_red  deaths_red  assists_red  kda_red
# 0      1.17    red            녹턴          7           5            4      2.2
# 1      3.00    red           카서스          4           1            1      5.0
# 2      5.00    red            탈론          2           1            1      3.0

# %%
dup_df = match_df.append(match_df)
dup_df
# Out:
#      lane team_x champName_blue  kills_blue  deaths_blue  assists_blue  \
# 0     Top   blue             세트           3            6             4
# 1  Jungle   blue             리신           2            2             4
# 2  Middle   blue            르블랑           3            1             2
# 0     Top   blue             세트           3            6             4
# 1  Jungle   blue             리신           2            2             4
# 2  Middle   blue            르블랑           3            1             2
#
#    kda_blue team_y champName_red  kills_red  deaths_red  assists_red  kda_red
# 0      1.17    red            녹턴          7           5            4      2.2
# 1      3.00    red           카서스          4           1            1      5.0
# 2      5.00    red            탈론          2           1            1      3.0
# 0      1.17    red            녹턴          7           5            4      2.2
# 1      3.00    red           카서스          4           1            1      5.0
# ...

# %%
dup_df
# Out:
#      lane team_x champName_blue  kills_blue  deaths_blue  assists_blue  \
# 0     Top   blue             세트           3            6             4
# 1  Jungle   blue             리신           2            2             4
# 2  Middle   blue            르블랑           3            1             2
# 0     Top   blue             세트           3            6             4
# 1  Jungle   blue             리신           2            2             4
# 2  Middle   blue            르블랑           3            1             2
#
#    kda_blue team_y champName_red  kills_red  deaths_red  assists_red  kda_red
# 0      1.17    red            녹턴          7           5            4      2.2
# 1      3.00    red           카서스          4           1            1      5.0
# 2      5.00    red            탈론          2           1            1      3.0
# 0      1.17    red            녹턴          7           5            4      2.2
# 1      3.00    red           카서스          4           1            1      5.0
# ...

# %%
dup_df.drop_duplicates(['assists_blue'],inplace=True)
dup_df
# Out:
#      lane team_x champName_blue  kills_blue  deaths_blue  assists_blue  \
# 0     Top   blue             세트           3            6             4
# 2  Middle   blue            르블랑           3            1             2
#
#    kda_blue team_y champName_red  kills_red  deaths_red  assists_red  kda_red
# 0      1.17    red            녹턴          7           5            4      2.2
# 2      5.00    red            탈론          2           1            1      3.0

# %% [markdown]
# ### read_csv
# - 외부에 저장된 csv파일을 불러올때
# ### to_csv
# - 데이터프레임을 외부로 저장할 때

# %%
match_df
# Out:
#      lane team_x champName_blue  kills_blue  deaths_blue  assists_blue  \
# 0     Top   blue             세트           3            6             4
# 1  Jungle   blue             리신           2            2             4
# 2  Middle   blue            르블랑           3            1             2
#
#    kda_blue team_y champName_red  kills_red  deaths_red  assists_red  kda_red
# 0      1.17    red            녹턴          7           5            4      2.2
# 1      3.00    red           카서스          4           1            1      5.0
# 2      5.00    red            탈론          2           1            1      3.0

# %%
match_df.to_csv('test.csv', index=False, encoding='cp949')

# %%
solo_rank_df = pd.read_csv('data_solo_rank.csv')

# %%
solo_rank_df.head()
# Out:
#        gameId  duration  version  participantId  championId       lane  side  \
# 0  5311499506      2196    11.14              1         412  Supporter  blue
# 1  5311499506      2196    11.14              2         517     Middle  blue
# 2  5311499506      2196    11.14              3         145        Bot  blue
# 3  5311499506      2196    11.14              4         234     Jungle  blue
# 4  5311499506      2196    11.14              5         266        Top  blue
#
#     win  damageDealt  damageTaken  ...   g21   g22    g23    g24    g25  \
# 0  True         5969        16076  ...  5256  5426   5647   6123   6411
# 1  True        21107        26083  ...  7191  7550   7779   8656   9200
# 2  True        28755        16542  ...  9180  9616  10379  11657  12485
# 3  True        18808        31963  ...  8705  8958   9253   9962  10525
# 4  True        15994        41212  ...  8364  8661   9182   9839  10084
#
#      g26    g27    g28    g29    g30
# ...

# %%
champion_df = pd.read_csv('info_champion.csv')

# %%
champion_df.head()
# Out:
#    championId champion_name_kr
# 0           1               애니
# 1           2              올라프
# 2           3              갈리오
# 3           4        트위스티드 페이트
# 4           5             신 짜오

# %%
solo_rank_df.columns
# Out:
# Index(['gameId', 'duration', 'version', 'participantId', 'championId', 'lane',
#        'side', 'win', 'damageDealt', 'damageTaken', 'gold', 'kills', 'deaths',
#        'assists', 'g5', 'g6', 'g7', 'g8', 'g9', 'g10', 'g11', 'g12', 'g13',
#        'g14', 'g15', 'g16', 'g17', 'g18', 'g19', 'g20', 'g21', 'g22', 'g23',
#        'g24', 'g25', 'g26', 'g27', 'g28', 'g29', 'g30'],
#       dtype='object')

# %%
my_df = solo_rank_df[['gameId','duration','participantId','championId','lane','side','win','damageDealt',
                     'kills','deaths','assists']]
my_df
# Out:
#             gameId  duration  participantId  championId       lane  side  \
# 0       5311499506      2196              1         412  Supporter  blue
# 1       5311499506      2196              2         517     Middle  blue
# 2       5311499506      2196              3         145        Bot  blue
# 3       5311499506      2196              4         234     Jungle  blue
# 4       5311499506      2196              5         266        Top  blue
# ...            ...       ...            ...         ...        ...   ...
# 999995  5346520241      1786              6          89  Supporter   red
# 999996  5346520241      1786              7          92        Top   red
# 999997  5346520241      1786              8          91     Middle   red
# 999998  5346520241      1786              9         141     Jungle   red
# 999999  5346520241      1786             10         202        Bot   red
#
#          win  damageDealt  kills  deaths  assists
# ...

# %%
my_df, champion_df

# %%
new_df = pd.merge(my_df, champion_df, on=['championId'], how='left')

# %%
new_df
# Out:
#             gameId  duration  participantId  championId       lane  side  \
# 0       5311499506      2196              1         412  Supporter  blue
# 1       5311499506      2196              2         517     Middle  blue
# 2       5311499506      2196              3         145        Bot  blue
# 3       5311499506      2196              4         234     Jungle  blue
# 4       5311499506      2196              5         266        Top  blue
# ...            ...       ...            ...         ...        ...   ...
# 999995  5346520241      1786              6          89  Supporter   red
# 999996  5346520241      1786              7          92        Top   red
# 999997  5346520241      1786              8          91     Middle   red
# 999998  5346520241      1786              9         141     Jungle   red
# 999999  5346520241      1786             10         202        Bot   red
#
#          win  damageDealt  kills  deaths  assists champion_name_kr
# ...

# %% [markdown]
# ### drop
# - delete column

# %%
new_df.drop(['championId'], axis=1, inplace=True)

# %%
new_df
# Out:
#             gameId  duration  participantId       lane  side   win  \
# 0       5311499506      2196              1  Supporter  blue  True
# 1       5311499506      2196              2     Middle  blue  True
# 2       5311499506      2196              3        Bot  blue  True
# 3       5311499506      2196              4     Jungle  blue  True
# 4       5311499506      2196              5        Top  blue  True
# ...            ...       ...            ...        ...   ...   ...
# 999995  5346520241      1786              6  Supporter   red  True
# 999996  5346520241      1786              7        Top   red  True
# 999997  5346520241      1786              8     Middle   red  True
# 999998  5346520241      1786              9     Jungle   red  True
# 999999  5346520241      1786             10        Bot   red  True
#
#         damageDealt  kills  deaths  assists champion_name_kr
# 0              5969      0       3       20              쓰레쉬
# ...

# %%
new_df['kda'] = new_df.apply(lambda x: round((x.kills+x.assists)/x.deaths, 2), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-230-821dedd1d31b> in <module>
# ----> 1 new_df['kda'] = new_df.apply(lambda x: round((x.kills+x.assists)/x.deaths, 2), axis=1)
#
# C:\ProgramData\Anaconda3\envs\py36\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7550             kwds=kwds,
#    7551         )
# -> 7552         return op.get_result()
#    7553
#    7554     def applymap(self, func) -> "DataFrame":
#
# C:\ProgramData\Anaconda3\envs\py36\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\envs\py36\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     274
# ...

# %%
k = 3
d = 0
a = 1

# %%
(k+a)/d
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-207-975aeedf2422> in <module>
# ----> 1 (k+a)/d
#
# ZeroDivisionError: division by zero

# %%
def kda_calc(k, d, a):
    try:
        kda = (k+a)/d
        return round(kda, 2)
    except:
        kda = 'Perfact'
        return kda

# %%
new_df['kda'] = new_df.apply(lambda x: kda_calc(x.kills, x.deaths, x.assists), axis=1)

# %%
new_df[new_df.deaths == 0]
# Out:
#             gameId  duration  participantId       lane  side    win  \
# 20      5311499642      1495              1        Top  blue   True
# 71      5311508690       966              2        Bot  blue   True
# 72      5311508690       966              3     Middle  blue   True
# 85      5311509029      1019              6  Supporter   red   True
# 90      5311509352       565              1        Top  blue  False
# ...            ...       ...            ...        ...   ...    ...
# 999886  5346516212       950              7        Bot   red   True
# 999888  5346516212       950              9     Jungle   red   True
# 999896  5346516354      1281              7  Supporter   red   True
# 999920  5346516966      1081              1  Supporter  blue   True
# 999921  5346516966      1081              2     Jungle  blue   True
#
#         damageDealt  kills  deaths  assists champion_name_kr      kda
# 20             6574      0       0        2               잭스  Perfact
# ...

# %%
new_df['kda'] = (new_df.kills+new_df.assists)/new_df.deaths

# %%
new_df
# Out:
#             gameId  duration  participantId       lane  side   win  \
# 0       5311499506      2196              1  Supporter  blue  True
# 1       5311499506      2196              2     Middle  blue  True
# 2       5311499506      2196              3        Bot  blue  True
# 3       5311499506      2196              4     Jungle  blue  True
# 4       5311499506      2196              5        Top  blue  True
# ...            ...       ...            ...        ...   ...   ...
# 999995  5346520241      1786              6  Supporter   red  True
# 999996  5346520241      1786              7        Top   red  True
# 999997  5346520241      1786              8     Middle   red  True
# 999998  5346520241      1786              9     Jungle   red  True
# 999999  5346520241      1786             10        Bot   red  True
#
#         damageDealt  kills  deaths  assists champion_name_kr        kda
# 0              5969      0       3       20              쓰레쉬   6.666667
# ...

# %%
new_df[new_df.deaths == 0]
# Out:
#             gameId  duration  participantId       lane  side    win  \
# 20      5311499642      1495              1        Top  blue   True
# 71      5311508690       966              2        Bot  blue   True
# 72      5311508690       966              3     Middle  blue   True
# 85      5311509029      1019              6  Supporter   red   True
# 90      5311509352       565              1        Top  blue  False
# ...            ...       ...            ...        ...   ...    ...
# 999886  5346516212       950              7        Bot   red   True
# 999888  5346516212       950              9     Jungle   red   True
# 999896  5346516354      1281              7  Supporter   red   True
# 999920  5346516966      1081              1  Supporter  blue   True
# 999921  5346516966      1081              2     Jungle  blue   True
#
#         damageDealt  kills  deaths  assists champion_name_kr  kda
# 20             6574      0       0        2               잭스  inf
# ...

# %%
new_df.fillna('Perfect', inplace=True)

# %%
new_df[new_df.deaths == 0]
# Out:
#             gameId  duration  participantId       lane  side    win  \
# 20      5311499642      1495              1        Top  blue   True
# 71      5311508690       966              2        Bot  blue   True
# 72      5311508690       966              3     Middle  blue   True
# 85      5311509029      1019              6  Supporter   red   True
# 90      5311509352       565              1        Top  blue  False
# ...            ...       ...            ...        ...   ...    ...
# 999886  5346516212       950              7        Bot   red   True
# 999888  5346516212       950              9     Jungle   red   True
# 999896  5346516354      1281              7  Supporter   red   True
# 999920  5346516966      1081              1  Supporter  blue   True
# 999921  5346516966      1081              2     Jungle  blue   True
#
#         damageDealt  kills  deaths  assists champion_name_kr      kda
# 20             6574      0       0        2               잭스      inf
# ...

# %% [markdown]
# ### conda install numpy

# %%
from numpy import inf

# %%
new_df[new_df.kda==inf] = 'Perfact'

# %%
new_df[new_df.deaths==0]
# Out:
#             gameId duration participantId       lane  side    win damageDealt  \
# 90      5311509352      565             1        Top  blue  False         768
# 96      5311509352      565             7     Jungle   red   True         137
# 460     5311568614      787             1     Middle  blue  False         931
# 645     5311588317      623             6        Top   red  False         442
# 666     5311588577      663             7     Jungle   red  False        1010
# ...            ...      ...           ...        ...   ...    ...         ...
# 998206  5346457671      192             7     Jungle   red   True         483
# 998207  5346457671      192             8     Middle   red   True          98
# 998208  5346457671      192             9        Bot   red   True         197
# 998209  5346457671      192            10  Supporter   red   True         344
# 998833  5346476556      639             4        Bot  blue  False         287
#
# ...

# %%
new_df
# Out:
#             gameId duration participantId       lane  side   win damageDealt  \
# 0       5311499506     2196             1  Supporter  blue  True        5969
# 1       5311499506     2196             2     Middle  blue  True       21107
# 2       5311499506     2196             3        Bot  blue  True       28755
# 3       5311499506     2196             4     Jungle  blue  True       18808
# 4       5311499506     2196             5        Top  blue  True       15994
# ...            ...      ...           ...        ...   ...   ...         ...
# 999995  5346520241     1786             6  Supporter   red  True        7562
# 999996  5346520241     1786             7        Top   red  True       15334
# 999997  5346520241     1786             8     Middle   red  True       27626
# 999998  5346520241     1786             9     Jungle   red  True       23209
# 999999  5346520241     1786            10        Bot   red  True       20059
#
# ...

# %% [markdown]
# - 전체단위로 연산. 컬럼을 선택
# - 결측값 NaN 체크
# - 비정상 값들을 대치하는 작업.

# %% [markdown]
# ### Crawling
# - conda install requests

# %%
import requests
